# %% [markdown]
# # 01 — Wstępna analiza danych
# Notebook pomocniczy dla Osoby 1.

# %%
import pandas as pd
from pathlib import Path

df = pd.read_csv(Path('../data/raw/marriage_data_india.csv'))
df.head()

# %%
df.shape, df.dtypes

# %%
df.isna().sum()

# %%
df['Divorce_Status'].value_counts(normalize=True), df['Marital_Satisfaction'].value_counts(normalize=True)

# %%
import matplotlib.pyplot as plt

df['Divorce_Status'].value_counts().plot(kind='bar')
plt.show()
